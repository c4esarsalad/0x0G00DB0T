# %% [markdown]
# <a href="https://colab.research.google.com/github/c4esarsalad/0x0G00DB0T/blob/main/M5Y1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# Загрузка изображения
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e2cbc68d-805a-4797-93d7-1a76e2794bbd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2cbc68d-805a-4797-93d7-1a76e2794bbd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image_path = list(uploaded.keys())[0]
image = cv2.imread("/content/nig keyboard.jpg")

# Теперь image - это объект, в котором хранятся все пиксели картинки.
# Чтобы посмотреть на значение пикселей, ты можешь просто распечать.
# А еще можешь исследовать свойства своей картинки
height, width, channels = image.shape
print("Ширина:", width)
print("Высота:", height)
print("Количество каналов:", channels)
# Out:
# Ширина: 735
# Высота: 509
# Количество каналов: 3

# %%
from google.colab.patches import cv2_imshow
import cv2
img = cv2.imread("/content/nig keyboard.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=735x509>

# %%
# !pip install rembg
# !pip install onnxruntime

# %%
from rembg import remove

input_path = "/content/dog.jpeg"
output_path = "nobg.jpeg"

with open(input_path, 'rb') as i:
    with open(output_path, 'wb') as o:
        input = i.read()
        output = remove(input)
        o.write(output)
# Out:
# ...
# 100%|████████████████████████████████████████| 176M/176M [00:00<00:00, 104GB/s]

# %%
pip install numpy

# %%
import numpy as np

def change_back(background, img):
    """ Функция для замены черного фона изображения на другую картинку.
    На вход принимается фон background и само изображение img.
    Далее начиная с верхнего левого угла изображения все черные пиксели (их значение = 0)
    будут заменены на пиксели из картинки с фоном"""

    x, y = 0, 0
    background = cv2.resize(background, (img.shape[1], img.shape[0]), interpolation = cv2.INTER_AREA)
    res = np.copy(background)
    place = res[y: y + img.shape[0], x: x + img.shape[1]]
    a = img[..., 3:].repeat(3, axis=2).astype('uint16')
    place[...] = (place.astype('uint16') * (255 - a) // 255) + img[..., :3].astype('uint16') * a // 255
    return res

# %%
img = cv2.imread("/content/minecraft.jpg", cv2.IMREAD_UNCHANGED)
image = cv2.imread("/content/nobg.jpeg", cv2.IMREAD_UNCHANGED)
change_back(img, image)
# Out:
# array([[[ 71, 115, 144],
#         [ 71, 115, 144],
#         [ 71, 115, 144],
#         ...,
#         [ 90,  91,  95],
#         [ 90,  91,  95],
#         [ 90,  91,  95]],
#
#        [[ 71, 115, 144],
#         [ 71, 115, 144],
#         [ 71, 115, 144],
#         ...,
#         [ 90,  91,  95],
#         [ 90,  91,  95],
#         [ 90,  91,  95]],
#
#        [[ 71, 115, 144],
#         [ 71, 115, 144],
#         [ 71, 115, 144],
#         ...,
#         [ 90,  91,  95],
#         [ 90,  91,  95],
#         [ 90,  91,  95]],
#
#        ...,
#
#        [[ 43,  80, 106],
#         [ 43,  80, 106],
#         [ 43,  80, 106],
#         ...,
#         [ 18,  60,  83],
#         [ 17,  59,  84],
#         [ 17,  59,  86]],
#
#        [[ 43,  80, 106],
#         [ 43,  80, 106],
#         [ 43,  80, 106],
#         ...,
#         [ 19,  60,  82],
#         [ 18,  59,  83],
#         [ 18,  58,  85]],
#
#        [[ 43,  80, 106],
#         [ 43,  80, 106],
#         [ 43,  80, 106],
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cv2.imwrite("result.png", change_back(img, image))
# Out:
# True
